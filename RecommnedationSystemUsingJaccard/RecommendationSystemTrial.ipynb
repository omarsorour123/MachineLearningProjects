# %%
# Import Dependencies
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist,squareform

# %%
#read_data
movies_df = pd.read_csv('movies.csv')

# %%
#explore the data
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#preprocessing
expanded_data = []
for i in range(len(movies_df)):
    # Extract title without year
    title = movies_df.loc[i, 'title'].split(" (")[0]
    #split the genres
    genres = movies_df.loc[i, 'genres'].split('|')
    #doing one to many relationship see the result to understand
    for genre in genres:
        expanded_data.append({'title': title, 'genre': genre})

# Create new DataFrame with expanded rows
movies_df = pd.DataFrame(expanded_data)

# %%
#the result
movies_df
# Out:
#                               title      genre
# 0                         Toy Story  Adventure
# 1                         Toy Story  Animation
# 2                         Toy Story   Children
# 3                         Toy Story     Comedy
# 4                         Toy Story    Fantasy
# ...                             ...        ...
# 22079         No Game No Life: Zero    Fantasy
# 22080                         Flint      Drama
# 22081  Bungo Stray Dogs: Dead Apple     Action
# 22082  Bungo Stray Dogs: Dead Apple  Animation
# 22083  Andrew Dice Clay: Dice Rules     Comedy
#
# [22084 rows x 2 columns]

# %%
#make it as table the rows is title and columns is genres
movies_df = pd.crosstab(movies_df['title'],movies_df['genre'])

# %%
#calculate jaccard distance the result 1d array
jaccard_dist=  pdist(movies_df.values,metric='jaccard')
#make it 2d array
squared_jaccard_dist = squareform(jaccard_dist)
#convert from distance to similarity which we foucs for
jaccard_similarity = 1- squared_jaccard_dist

# %%
#the result
print(jaccard_similarity)
# Out:
# [[1.         0.125      0.2        ... 0.4        0.         0.        ]
#  [0.125      1.         0.         ... 0.14285714 0.16666667 0.16666667]
#  [0.2        0.         1.         ... 0.         0.         0.33333333]
#  ...
#  [0.4        0.14285714 0.         ... 1.         0.         0.        ]
#  [0.         0.16666667 0.         ... 0.         1.         0.33333333]
#  [0.         0.16666667 0.33333333 ... 0.         0.33333333 1.        ]]

# %%
#make it as dataframe with title as column and row to get the relatio between two movies like
#distance_df['toy story']['jumanji']
distance_df = pd.DataFrame(jaccard_similarity,index =movies_df.index,columns=movies_df.index)

# %%
#the result
distance_df
# Out:
# title                                  '71  'Hellboy': The Seeds of Creation  \
# title
# '71                               1.000000                          0.125000
# 'Hellboy': The Seeds of Creation  0.125000                          1.000000
# 'Round Midnight                   0.200000                          0.000000
# 'Salem's Lot                      0.333333                          0.000000
# 'Til There Was You                0.200000                          0.000000
# ...                                    ...                               ...
# eXistenZ                          0.400000                          0.142857
# xXx                               0.400000                          0.142857
# xXx: State of the Union           0.400000                          0.142857
# ¡Three Amigos!                    0.000000                          0.166667
# À nous la liberté                 0.000000                          0.166667
#
# title                             'Round Midnight  'Salem's Lot  \
# title
# '71                                      0.200000      0.333333
# 'Hellboy': The Seeds of Creation         0.000000      0.000000
# 'Round Midnight                          1.000000      0.200000
# 'Salem's Lot                             0.200000      1.000000
# 'Til There Was You                       0.333333      0.200000
# ...                                           ...           ...
# eXistenZ                                 0.000000      0.166667
# xXx                                      0.000000      0.166667
# xXx: State of the Union                  0.000000      0.166667
# ¡Three Amigos!                           0.000000      0.000000
# À nous la liberté                        0.333333      0.000000
#
# title                             'Til There Was You  \
# title
# '71                                         0.200000
# 'Hellboy': The Seeds of Creation            0.000000
# 'Round Midnight                             0.333333
# 'Salem's Lot                                0.200000
# 'Til There Was You                          1.000000
# ...                                              ...
# eXistenZ                                    0.000000
# xXx                                         0.000000
# xXx: State of the Union                     0.000000
# ¡Three Amigos!                              0.000000
# À nous la liberté                           0.000000
#
# title                             'Tis the Season for Love  'burbs, The  \
# title
# '71                                                    0.0          0.0
# 'Hellboy': The Seeds of Creation                       0.0          0.2
# 'Round Midnight                                        0.0          0.0
# 'Salem's Lot                                           0.0          0.0
# 'Til There Was You                                     0.5          0.0
# ...                                                    ...          ...
# eXistenZ                                               0.0          0.0
# xXx                                                    0.0          0.0
# xXx: State of the Union                                0.0          0.0
# ¡Three Amigos!                                         0.0          0.5
# À nous la liberté                                      0.0          0.5
#
# title                             'night Mother  (500) Days of Summer  \
# title
# '71                                        0.25              0.166667
# 'Hellboy': The Seeds of Creation           0.00              0.142857
# 'Round Midnight                            0.50              0.250000
# 'Salem's Lot                               0.25              0.166667
# 'Til There Was You                         0.50              0.666667
# ...                                         ...                   ...
# eXistenZ                                   0.00              0.000000
# xXx                                        0.00              0.000000
# xXx: State of the Union                    0.00              0.000000
# ¡Three Amigos!                             0.00              0.250000
# À nous la liberté                          0.00              0.250000
#
# title                             *batteries not included  ...      Zulu  \
# title                                                      ...
# '71                                              0.000000  ...  0.600000
# 'Hellboy': The Seeds of Creation                 0.285714  ...  0.111111
# 'Round Midnight                                  0.000000  ...  0.000000
# 'Salem's Lot                                     0.000000  ...  0.142857
# 'Til There Was You                               0.000000  ...  0.000000
# ...                                                   ...  ...       ...
# eXistenZ                                         0.166667  ...  0.333333
# xXx                                              0.000000  ...  0.600000
# xXx: State of the Union                          0.000000  ...  0.600000
# ¡Three Amigos!                                   0.200000  ...  0.000000
# À nous la liberté                                0.200000  ...  0.000000
#
# title                             [REC]  [REC]²  [REC]³ 3 Génesis  \
# title
# '71                                0.40    0.20              0.20
# 'Hellboy': The Seeds of Creation   0.00    0.00              0.00
# 'Round Midnight                    0.25    0.00              0.00
# 'Salem's Lot                       0.75    0.50              0.50
# 'Til There Was You                 0.25    0.00              0.00
# ...                                 ...     ...               ...
# eXistenZ                           0.20    0.25              0.25
# xXx                                0.20    0.25              0.25
# xXx: State of the Union            0.20    0.25              0.25
# ¡Three Amigos!                     0.00    0.00              0.00
# À nous la liberté                  0.00    0.00              0.00
#
# title                             anohana: The Flower We Saw That Day - The Movie  \
# title
# '71                                                                      0.200000
# 'Hellboy': The Seeds of Creation                                         0.000000
# 'Round Midnight                                                          0.333333
# 'Salem's Lot                                                             0.200000
# 'Til There Was You                                                       0.333333
# ...                                                                           ...
# eXistenZ                                                                 0.000000
# xXx                                                                      0.000000
# xXx: State of the Union                                                  0.000000
# ¡Three Amigos!                                                           0.000000
# À nous la liberté                                                        0.000000
#
# title                             eXistenZ       xXx  xXx: State of the Union  \
# title
# '71                               0.400000  0.400000                 0.400000
# 'Hellboy': The Seeds of Creation  0.142857  0.142857                 0.142857
# 'Round Midnight                   0.000000  0.000000                 0.000000
# 'Salem's Lot                      0.166667  0.166667                 0.166667
# 'Til There Was You                0.000000  0.000000                 0.000000
# ...                                    ...       ...                      ...
# eXistenZ                          1.000000  0.500000                 0.500000
# xXx                               0.500000  1.000000                 1.000000
# xXx: State of the Union           0.500000  1.000000                 1.000000
# ¡Three Amigos!                    0.000000  0.000000                 0.000000
# À nous la liberté                 0.000000  0.000000                 0.000000
#
# title                             ¡Three Amigos!  À nous la liberté
# title
# '71                                     0.000000           0.000000
# 'Hellboy': The Seeds of Creation        0.166667           0.166667
# 'Round Midnight                         0.000000           0.333333
# 'Salem's Lot                            0.000000           0.000000
# 'Til There Was You                      0.000000           0.000000
# ...                                          ...                ...
# eXistenZ                                0.000000           0.000000
# xXx                                     0.000000           0.000000
# xXx: State of the Union                 0.000000           0.000000
# ¡Three Amigos!                          1.000000           0.333333
# À nous la liberté                       0.333333           1.000000
#
# [9412 rows x 9412 columns]

# %%
#testing
watched_movies = ['Toy Story','Jumanji']
testing = movies_df.reindex(watched_movies)

# %%
ans=[]
for i in range(len(watched_movies)):
  ans.append(distance_df[watched_movies[i]].sort_values(ascending=False)[:2])
print(ans)
#most 2 similer movies for toy sotry and jumanji as result
# Out:
# [title
# Emperor's New Groove, The    1.0
# Monsters, Inc.               1.0
# Name: Toy Story, dtype: float64, title
# Harry Potter and the Sorcerer's Stone        1.0
# Chronicles of Narnia: Prince Caspian, The    1.0
# Name: Jumanji, dtype: float64]
